# %%
import numpy as np
x = np.array(1)

x.ndim
# Out:
# 0

# %%
x = np.array([1,2,3])
x.ndim
# Out:
# 1

# %%
x = np.array([[1,2,3],
              [4,5,6]])
x.ndim
# Out:
# 2

# %%
import numpy as np

class Variable:
    def __init__(self,data):
        self.data = data

class Function:
    def __call__(self,input):
        x = input.data
        y = x**2
        output = Variable(y)
        return output

# %%
x = Variable(np.array(10))
f = Function()
y = f(x)
print(type(y))
print(y.data)
# Out:
# <class '__main__.Variable'>
# 100
